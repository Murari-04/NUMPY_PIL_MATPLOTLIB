# %%
#pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\Lenovo\Downloads\chennai-super-kings-indian-premier-league-ipl-ipl-2021-7680x4320-4938.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (3862, 4203, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[248, 190,   2],
#         [249, 191,   3],
#         [248, 193,   2],
#         ...,
#         [250, 193,   2],
#         [246, 194,   0],
#         [255, 210,   8]],
#
#        [[251, 196,   5],
#         [248, 195,   1],
#         [246, 193,   0],
#         ...,
#         [250, 193,   2],
#         [245, 193,   0],
#         [255, 208,   6]],
#
#        [[244, 197,   0],
#         [243, 196,   0],
#         [242, 195,   0],
#         ...,
#         [246, 192,   0],
#         [241, 192,   0],
#         [252, 207,   2]],
#
#        ...,
#
#        [[251, 218,   1],
#         [251, 218,   1],
#         [251, 218,   1],
#         ...,
#         [252, 224,   0],
#         [252, 224,   0],
#         [252, 224,   0]],
#
#        [[251, 218,   1],
#         [251, 218,   1],
#         [251, 218,   1],
#         ...,
#         [252, 224,   0],
#         [252, 224,   0],
#         [252, 224,   0]],
#
#        [[251, 218,   1],
#         [251, 218,   1],
#         [251, 218,   1],
# ...

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\Lenovo\Downloads\chennai-super-kings-indian-premier-league-ipl-ipl-2021-7680x4320-4938.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (3862, 4203)

# %%
img_gray
# Out:
# array([[186, 187, 188, ..., 188, 187, 201],
#        [191, 189, 187, ..., 188, 186, 199],
#        [188, 187, 186, ..., 186, 184, 197],
#        ...,
#        [203, 203, 203, ..., 207, 207, 207],
#        [203, 203, 203, ..., 207, 207, 207],
#        [203, 203, 203, ..., 207, 207, 207]],
#       shape=(3862, 4203), dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(47)

# %%
img_gray.max()
# Out:
# np.uint8(224)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='Accent')

# %%
fix_img.shape
# Out:
# (3862, 4203, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(1931,2101))

# %%
fix_img_1.shape
# Out:
# (2101, 1931, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2
# Out:
# array([[[249, 193,   3],
#         [246, 194,   1],
#         [244, 196,   0],
#         ...,
#         [250, 190,   3],
#         [248, 193,   1],
#         [255, 209,   7]],
#
#        [[242, 198,   0],
#         [243, 201,   0],
#         [247, 208,   1],
#         ...,
#         [249, 190,   2],
#         [243, 192,   0],
#         [253, 208,   3]],
#
#        [[251, 220,   1],
#         [253, 223,   3],
#         [252, 223,   2],
#         ...,
#         [247, 191,   1],
#         [243, 196,   0],
#         [255, 216,   8]],
#
#        ...,
#
#        [[251, 218,   1],
#         [251, 218,   1],
#         [251, 218,   1],
#         ...,
#         [252, 224,   0],
#         [252, 224,   0],
#         [252, 224,   0]],
#
#        [[251, 218,   1],
#         [251, 218,   1],
#         [251, 218,   1],
#         ...,
#         [252, 224,   0],
#         [252, 224,   0],
#         [252, 224,   0]],
#
#        [[251, 218,   1],
#         [251, 218,   1],
#         [251, 218,   1],
# ...

# %%
plt.imshow(fix_img_2)

# %%
img3 = cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2,1)
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2,3)
plt.imshow(img3)

# %%
cv2.imwrite('new genai image.jpg',fix_img_2)
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\Lenovo'
