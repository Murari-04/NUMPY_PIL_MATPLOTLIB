# %%
import cv2
nimg = cv2.imread(r'C:\Users\Lenovo\Downloads\nature.jpg')

# %%
wrong_img= cv2.imread(r'C:\Users\Lenovo\Downloads\dog.img')

# %%
type(wrong_img)
# Out:
# NoneType

# %%
type(nimg)
# Out:
# numpy.ndarray

# %%
import cv2
nimg = cv2.imread(r'C:\Users\Lenovo\Downloads\nature.jpg')

cv2.imshow('nature', nimg)

cv2.waitKey()
# Out:
# -1

# %%
-1
# Out:
# -1

# %%
import cv2
nimg = cv2.imread(r'C:\Users\Lenovo\Downloads\nature.jpg')

while True:
    cv2.imshow('nature', nimg)

    if cv2.waitKey(1) & 0xFF ==27:
        break
cv2.destroyAllWindows()
